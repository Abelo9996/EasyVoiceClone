# %% [markdown]
# # Easy Voice Cloner Quickstart
#
# This notebook demonstrates the basic workflow for cloning a voice and synthesizing speech.

# %%
# Step 1: Preprocess audio samples
from utils.audio import preprocess_audio
audio_files = preprocess_audio('data/example_audio')
print(audio_files)

# %%
# Step 2: Transcribe audio (optional)
from utils.transcription import transcribe_audio
transcripts = transcribe_audio(audio_files)
print(transcripts)

# %%
# Step 3: Train voice clone (dummy example)
# !python train.py --audio_dir data/example_audio --output models/my_voice_clone.pt

# %%
# Step 4: Run inference (dummy example)
# !python infer.py --text 'Hello world' --voice models/my_voice_clone.pt --output output.wav

# %% [markdown]
# ---
# **Note:** This is a starter notebook.
# - Model training and inference are not yet implemented.
# - See README for details and TODOs.
